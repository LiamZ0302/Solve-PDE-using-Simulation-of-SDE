# %%
import matplotlib.pyplot as plt
import numpy as np
import math as m
from sklearn import linear_model

# %%
output = np.loadtxt('output.txt')
output.shape
# Out:
# (10, 2)

# %%
dts = output[:, 0]
error = output[:, 1]
s_dts = np.sqrt(dts)
regr = linear_model.LinearRegression()
regr.fit(s_dts.reshape(-1, 1), error)
plt.figure(figsize = (16, 9), dpi = 120)
plt.plot(s_dts, error, linewidth = 0, marker = 'o', markersize = 8)
plt.plot(s_dts, regr.predict(s_dts.reshape(-1, 1)), color='red', linewidth=2)
plt.ylabel("Relative Error")
plt.xlabel("Square Root of Step Length")
plt.show()

# %%
# Out:
# array([0.22260503, 0.19769041, 0.35041261, 0.43699313, 0.44900445,
#        0.5229847 , 0.54829645, 0.5988347 , 0.68848166, 0.69534955])
